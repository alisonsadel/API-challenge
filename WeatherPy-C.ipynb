# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint 


# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 597

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
# Create lists

city = []
lat = []
lng = []
maxtemp = []
humidity = []
cloudiness = []
windspeed = []
country = []
date = [] 

records = 1

print("Beginning Data Retrieval")
print("-----------------------------") 

for citi in cities:
    url = f"http://api.openweathermap.org/data/2.5/weather?q={citi}&appid={weather_api_key}"
    response = requests.get(url).json()
    time.sleep(1.1)
    try: 

    #print(json.dumps(response, indent=4, sort_keys=True))
    #pprint(response)
        city.append(response["name"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        maxtemp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        windspeed.append(response["wind"]["speed"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        print(f'processing record {records} | {citi}') 
        records += 1
    except KeyError:
        print("city not found, skipping to next...")
# Out:
# Beginning Data Retrieval
# -----------------------------
# processing record 1 | coruripe
# processing record 2 | georgetown
# processing record 3 | petropavlovsk-kamchatskiy
# processing record 4 | hilo
# processing record 5 | cape town
# processing record 6 | komsomolskiy
# processing record 7 | olinda
# processing record 8 | lohja
# processing record 9 | albany
# processing record 10 | hermanus
# processing record 11 | grindavik
# processing record 12 | vestmannaeyjar
# processing record 13 | mataura
# processing record 14 | renala khurd
# processing record 15 | avarua
# processing record 16 | vaini
# processing record 17 | harper
# processing record 18 | hobyo
# processing record 19 | kincardine
# processing record 20 | arraial do cabo
# processing record 21 | tuktoyaktuk
# processing record 22 | praia da vitoria
# processing record 23 | ushuaia
# processing record 24 | tessalit
# city not found, skipping to next...
# processing record 25 | atuona
# processing record 26 | tiksi
# processing record 27 | nikolskoye
# processing record 28 | sangmelima
# processing record 29 | kapaa
# processing record 30 | busselton
# city not found, skipping to next...
# processing record 31 | najran
# processing record 32 | yulara
# processing record 33 | stranda
# processing record 34 | buala
# processing record 35 | thinadhoo
# processing record 36 | san cristobal
# processing record 37 | pisco
# processing record 38 | barrow
# processing record 39 | san pedro
# processing record 40 | los llanos de aridane
# processing record 41 | mahebourg
# processing record 42 | phek
# processing record 43 | turinsk
# city not found, skipping to next...
# processing record 44 | la asuncion
# processing record 45 | manubul
# processing record 46 | pangnirtung
# city not found, skipping to next...
# processing record 47 | sidmouth
# processing record 48 | bambous virieux
# processing record 49 | touros
# processing record 50 | preobrazheniye
# processing record 51 | sault sainte marie
# city not found, skipping to next...
# processing record 52 | rikitea
# processing record 53 | upernavik
# processing record 54 | pevek
# processing record 55 | okha
# processing record 56 | east london
# processing record 57 | port lincoln
# processing record 58 | cherskiy
# processing record 59 | nampula
# processing record 60 | port elizabeth
# processing record 61 | new norfolk
# processing record 62 | taoudenni
# processing record 63 | gamba
# processing record 64 | rosetta
# processing record 65 | manokwari
# processing record 66 | tarko-sale
# processing record 67 | ponta do sol
# processing record 68 | cockburn town
# processing record 69 | kongolo
# processing record 70 | faanui
# processing record 71 | punta arenas
# processing record 72 | caravelas
# processing record 73 | bluff
# processing record 74 | broome
# processing record 75 | erenhot
# processing record 76 | yerbogachen
# processing record 77 | sao filipe
# processing record 78 | yangambi
# processing record 79 | batagay
# processing record 80 | tiznit
# processing record 81 | hithadhoo
# processing record 82 | flinders
# processing record 83 | talnakh
# processing record 84 | namibe
# processing record 85 | paamiut
# processing record 86 | babu
# city not found, skipping to next...
# processing record 87 | chuy
# processing record 88 | shache
# processing record 89 | jamestown
# processing record 90 | vila
# processing record 91 | kharp
# processing record 92 | saint-pierre
# processing record 93 | butaritari
# processing record 94 | norrtalje
# processing record 95 | torbay
# processing record 96 | paso de los toros
# processing record 97 | minden
# processing record 98 | kavieng
# processing record 99 | san patricio
# processing record 100 | kahului
# city not found, skipping to next...
# processing record 101 | maceio
# processing record 102 | puerto escondido
# processing record 103 | saint-philippe
# processing record 104 | sioux lookout
# processing record 105 | bredasdorp
# processing record 106 | norman wells
# city not found, skipping to next...
# processing record 107 | shevchenkove
# processing record 108 | constitucion
# processing record 109 | victoria
# processing record 110 | cap malheureux
# processing record 111 | port alfred
# processing record 112 | andros town
# processing record 113 | ust-omchug
# city not found, skipping to next...
# processing record 114 | camacha
# processing record 115 | hofn
# processing record 116 | guarapari
# processing record 117 | ribeira grande
# processing record 118 | bengkulu
# processing record 119 | salalah
# processing record 120 | provideniya
# processing record 121 | tromso
# processing record 122 | castro
# processing record 123 | florianopolis
# processing record 124 | lagoa
# city not found, skipping to next...
# processing record 125 | medicine hat
# processing record 126 | cessnock
# city not found, skipping to next...
# processing record 127 | oyama
# processing record 128 | bemidji
# processing record 129 | adrar
# processing record 130 | charters towers
# processing record 131 | kodiak
# processing record 132 | dingle
# processing record 133 | teknaf
# processing record 134 | rudabanya
# processing record 135 | khatanga
# processing record 136 | deputatskiy
# processing record 137 | yellowknife
# processing record 138 | haines junction
# processing record 139 | puerto ayora
# processing record 140 | puerto pailas
# city not found, skipping to next...
# processing record 141 | bathsheba
# processing record 142 | millau
# processing record 143 | aguie
# processing record 144 | zhigansk
# processing record 145 | imeni babushkina
# processing record 146 | bilma
# processing record 147 | qaanaaq
# processing record 148 | ostrovnoy
# processing record 149 | lorengau
# processing record 150 | palmer
# processing record 151 | lebu
# city not found, skipping to next...
# processing record 152 | batemans bay
# processing record 153 | goderich
# processing record 154 | rio grande
# processing record 155 | melo
# processing record 156 | saskylakh
# processing record 157 | maloy
# processing record 158 | kutum
# processing record 159 | bonthe
# processing record 160 | srednekolymsk
# processing record 161 | hobart
# processing record 162 | neiafu
# processing record 163 | anadyr
# processing record 164 | lookan
# processing record 165 | carnarvon
# processing record 166 | saint anthony
# processing record 167 | ancud
# processing record 168 | rosendal
# processing record 169 | asau
# city not found, skipping to next...
# processing record 170 | gelibolu
# processing record 171 | porto belo
# processing record 172 | husavik
# processing record 173 | bethel
# processing record 174 | straumen
# processing record 175 | randazzo
# processing record 176 | richards bay
# processing record 177 | kandalaksha
# processing record 178 | cidreira
# processing record 179 | zilair
# city not found, skipping to next...
# processing record 180 | shchebetovka
# processing record 181 | pemagatsel
# processing record 182 | yola
# city not found, skipping to next...
# processing record 183 | bobota
# processing record 184 | mar del plata
# processing record 185 | garden city
# city not found, skipping to next...
# city not found, skipping to next...
# processing record 186 | praia
# processing record 187 | selma
# processing record 188 | isangel
# processing record 189 | sibolga
# processing record 190 | chokurdakh
# processing record 191 | safford
# processing record 192 | krasnoselkup
# processing record 193 | salta
# processing record 194 | korla
# processing record 195 | lompoc
# processing record 196 | kirakira
# processing record 197 | mundo nuevo
# processing record 198 | jumla
# processing record 199 | codrington
# processing record 200 | kalabo
# processing record 201 | kedrovyy
# processing record 202 | brownwood
# processing record 203 | port blair
# processing record 204 | geraldton
# processing record 205 | bubaque
# processing record 206 | longyearbyen
# processing record 207 | filingue
# processing record 208 | oga
# city not found, skipping to next...
# processing record 209 | thompson
# processing record 210 | zlitan
# processing record 211 | dikson
# processing record 212 | nova odesa
# processing record 213 | port moresby
# processing record 214 | sterling
# processing record 215 | philippeville
# processing record 216 | evensk
# processing record 217 | kranuan
# processing record 218 | atambua
# processing record 219 | coihaique
# processing record 220 | lazaro cardenas
# processing record 221 | halifax
# processing record 222 | chaohu
# processing record 223 | ouesso
# processing record 224 | souillac
# processing record 225 | beringovskiy
# processing record 226 | lavrentiya
# processing record 227 | eureka
# processing record 228 | half moon bay
# processing record 229 | airai
# processing record 230 | mogadishu
# processing record 231 | berdigestyakh
# processing record 232 | cabo san lucas
# processing record 233 | lakselv
# city not found, skipping to next...
# processing record 234 | carbonia
# processing record 235 | sitka
# processing record 236 | dhidhdhoo
# processing record 237 | starobaltachevo
# processing record 238 | abu dhabi
# processing record 239 | san ramon
# processing record 240 | ankara
# processing record 241 | behat
# processing record 242 | klaksvik
# processing record 243 | bara
# processing record 244 | kupang
# processing record 245 | dzialdowo
# processing record 246 | nanortalik
# processing record 247 | roma
# processing record 248 | shilong
# processing record 249 | svetlyy
# processing record 250 | fort nelson
# processing record 251 | kamenka
# processing record 252 | sisimiut
# processing record 253 | alofi
# processing record 254 | biak
# processing record 255 | kaitangata
# processing record 256 | katsuura
# processing record 257 | narsaq
# city not found, skipping to next...
# processing record 258 | sovetskiy
# processing record 259 | sangar
# processing record 260 | jiwani
# processing record 261 | vanimo
# processing record 262 | kieta
# processing record 263 | fort saint james
# processing record 264 | nelson bay
# processing record 265 | nhulunbuy
# processing record 266 | peno
# processing record 267 | saldanha
# processing record 268 | avera
# processing record 269 | talcahuano
# city not found, skipping to next...
# processing record 270 | guerrero negro
# processing record 271 | san policarpo
# city not found, skipping to next...
# processing record 272 | cascais
# processing record 273 | iqaluit
# processing record 274 | ilulissat
# processing record 275 | tual
# processing record 276 | havoysund
# processing record 277 | llanes
# processing record 278 | raymond
# processing record 279 | gomel
# processing record 280 | antsohihy
# processing record 281 | synya
# processing record 282 | aguimes
# processing record 283 | clyde river
# processing record 284 | berlevag
# city not found, skipping to next...
# processing record 285 | madrid
# city not found, skipping to next...
# processing record 286 | iquique
# processing record 287 | hasaki
# processing record 288 | esperance
# processing record 289 | vila velha
# processing record 290 | marica
# processing record 291 | yumen
# processing record 292 | samarai
# processing record 293 | tamluk
# processing record 294 | ossora
# processing record 295 | ellsworth
# processing record 296 | zapolyarnyy
# processing record 297 | broken hill
# processing record 298 | la ronge
# processing record 299 | fairbanks
# processing record 300 | chepareria
# processing record 301 | pauini
# processing record 302 | zunil
# processing record 303 | sur
# processing record 304 | kjollefjord
# processing record 305 | labuhan
# processing record 306 | ahipara
# city not found, skipping to next...
# processing record 307 | ust-nera
# processing record 308 | kruisfontein
# processing record 309 | fergus falls
# processing record 310 | saint george
# processing record 311 | rocha
# city not found, skipping to next...
# processing record 312 | reconquista
# processing record 313 | vrangel
# processing record 314 | ust-barguzin
# processing record 315 | starodub
# processing record 316 | fairhope
# processing record 317 | ewo
# processing record 318 | brae
# processing record 319 | pingliang
# processing record 320 | opuwo
# city not found, skipping to next...
# city not found, skipping to next...
# processing record 321 | sao goncalo do amarante
# processing record 322 | severo-kurilsk
# processing record 323 | sicamous
# processing record 324 | oktyabrskoye
# processing record 325 | stephenville
# processing record 326 | acajutla
# processing record 327 | cayenne
# processing record 328 | tuatapere
# processing record 329 | arlit
# processing record 330 | san rafael
# processing record 331 | hokitika
# processing record 332 | yurimaguas
# processing record 333 | aranos
# processing record 334 | port macquarie
# processing record 335 | gujan-mestras
# city not found, skipping to next...
# processing record 336 | tyret pervaya
# processing record 337 | mantes-la-ville
# processing record 338 | tarakan
# processing record 339 | athabasca
# processing record 340 | hambantota
# processing record 341 | xining
# processing record 342 | manakara
# processing record 343 | ryotsu
# processing record 344 | grand-lahou
# processing record 345 | kadhan
# processing record 346 | demyansk
# processing record 347 | sept-iles
# city not found, skipping to next...
# processing record 348 | suntar
# processing record 349 | luderitz
# processing record 350 | hamilton
# processing record 351 | pointe michel
# processing record 352 | torbat-e jam
# processing record 353 | kulhudhuffushi
# city not found, skipping to next...
# processing record 354 | coquimbo
# processing record 355 | crotone
# processing record 356 | bandiagara
# processing record 357 | bowen
# processing record 358 | mehamn
# processing record 359 | dukat
# processing record 360 | aklavik
# processing record 361 | albion
# processing record 362 | neuquen
# processing record 363 | romny
# city not found, skipping to next...
# processing record 364 | douglas
# processing record 365 | norfolk
# processing record 366 | tasiilaq
# processing record 367 | kodinar
# processing record 368 | forte dei marmi
# processing record 369 | vila franca do campo
# processing record 370 | sulangan
# processing record 371 | saint stephen
# processing record 372 | oster
# city not found, skipping to next...
# processing record 373 | palauig
# processing record 374 | kiunga
# city not found, skipping to next...
# processing record 375 | naze
# processing record 376 | yarensk
# processing record 377 | sao joao da barra
# processing record 378 | kasempa
# processing record 379 | batesville
# processing record 380 | fukue
# processing record 381 | grand gaube
# processing record 382 | tokat
# processing record 383 | santiago
# processing record 384 | dhoraji
# processing record 385 | arbazh
# processing record 386 | solton
# processing record 387 | baghdad
# processing record 388 | tupelo
# processing record 389 | fort wellington
# processing record 390 | shakawe
# processing record 391 | laguna
# processing record 392 | olga
# processing record 393 | kiama
# processing record 394 | chapadinha
# city not found, skipping to next...
# processing record 395 | soe
# processing record 396 | shahr-e babak
# processing record 397 | teya
# processing record 398 | roald
# processing record 399 | pekan
# processing record 400 | sokoto
# processing record 401 | asfi
# processing record 402 | tczew
# processing record 403 | kangaatsiaq
# processing record 404 | jibuti
# processing record 405 | premnitz
# processing record 406 | la libertad
# processing record 407 | healdsburg
# processing record 408 | burnie
# processing record 409 | severo-yeniseyskiy
# processing record 410 | henties bay
# processing record 411 | wukari
# processing record 412 | carutapera
# processing record 413 | mumford
# processing record 414 | banyo
# processing record 415 | rawson
# processing record 416 | banting
# processing record 417 | nijar
# processing record 418 | kotido
# processing record 419 | oksfjord
# processing record 420 | zaysan
# processing record 421 | yar-sale
# processing record 422 | westport
# processing record 423 | igarka
# city not found, skipping to next...
# processing record 424 | beitbridge
# processing record 425 | laje
# processing record 426 | ust-ishim
# processing record 427 | maua
# processing record 428 | margate
# processing record 429 | otavi
# processing record 430 | qasigiannguit
# processing record 431 | chenghai
# processing record 432 | vostok
# processing record 433 | fortuna
# processing record 434 | sayyan
# processing record 435 | campbell river
# processing record 436 | tecpan
# city not found, skipping to next...
# processing record 437 | girau do ponciano
# city not found, skipping to next...
# processing record 438 | comodoro rivadavia
# processing record 439 | dakar
# processing record 440 | anchorage
# processing record 441 | pacific grove
# processing record 442 | katherine
# processing record 443 | manutuke
# processing record 444 | olden
# processing record 445 | bom jesus
# processing record 446 | tecoanapa
# processing record 447 | egvekinot
# processing record 448 | tambura
# processing record 449 | vao
# processing record 450 | benghazi
# processing record 451 | angoche
# processing record 452 | hami
# processing record 453 | te anau
# processing record 454 | kabo
# processing record 455 | tahe
# processing record 456 | ostersund
# processing record 457 | noumea
# processing record 458 | road town
# processing record 459 | maniitsoq
# processing record 460 | pundaguitan
# processing record 461 | mahina
# processing record 462 | ust-kan
# processing record 463 | missoula
# processing record 464 | tikhvin
# processing record 465 | mikulovice
# processing record 466 | bollnas
# processing record 467 | horta
# processing record 468 | batticaloa
# processing record 469 | jamame
# processing record 470 | sola
# processing record 471 | tagusao
# city not found, skipping to next...
# processing record 472 | marzuq
# processing record 473 | lewisporte
# processing record 474 | iralaya
# processing record 475 | olovyannaya
# processing record 476 | yetkul
# processing record 477 | akyab
# processing record 478 | carmen
# processing record 479 | belaya gora
# processing record 480 | mutare
# processing record 481 | sabha
# processing record 482 | piltene
# processing record 483 | vico equense
# processing record 484 | kolondieba
# processing record 485 | wana
# processing record 486 | raga
# processing record 487 | ardakan
# processing record 488 | oriximina
# processing record 489 | beloha
# processing record 490 | tuy hoa
# processing record 491 | miajadas
# processing record 492 | naryan-mar
# processing record 493 | botad
# processing record 494 | key largo
# processing record 495 | kloulklubed
# processing record 496 | dzaoudzi
# processing record 497 | port hedland
# processing record 498 | carauari
# processing record 499 | port-gentil
# city not found, skipping to next...
# processing record 500 | olafsvik
# processing record 501 | jinxiang
# processing record 502 | fairmont
# processing record 503 | winnemucca
# processing record 504 | altay
# processing record 505 | doha
# processing record 506 | koumac
# processing record 507 | floro
# processing record 508 | elizabeth city
# processing record 509 | cozumel
# processing record 510 | fengzhen
# city not found, skipping to next...
# processing record 511 | kysyl-syr
# processing record 512 | poronaysk
# processing record 513 | tallahassee
# processing record 514 | vitim
# processing record 515 | bandarbeyla
# city not found, skipping to next...
# processing record 516 | karratha
# processing record 517 | porto torres
# processing record 518 | aligudarz
# processing record 519 | santa cruz de la palma
# city not found, skipping to next...
# processing record 520 | vytegra
# processing record 521 | jizan
# processing record 522 | krk
# processing record 523 | mugumu
# processing record 524 | gravdal
# processing record 525 | omboue
# processing record 526 | quatre cocos
# processing record 527 | bulgan
# processing record 528 | college
# processing record 529 | porto novo
# processing record 530 | luganville
# processing record 531 | chickasha
# processing record 532 | belmonte
# processing record 533 | nkhotakota
# processing record 534 | farafangana
# processing record 535 | fallon
# city not found, skipping to next...
# processing record 536 | mount isa
# processing record 537 | xihe
# processing record 538 | luanda
# processing record 539 | wadi musa
# processing record 540 | america dourada
# city not found, skipping to next...
# processing record 541 | baijiantan
# processing record 542 | aswan
# processing record 543 | edson
# processing record 544 | inta
# processing record 545 | port hardy
# processing record 546 | lampa
# city not found, skipping to next...
# processing record 547 | boffa
# processing record 548 | vardo
# processing record 549 | twentynine palms
# processing record 550 | tarauaca

# %%
pprint(response)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 69},
#  'cod': 200,
#  'coord': {'lat': -8.16, 'lon': -70.77},
#  'dt': 1608837769,
#  'id': 3661980,
#  'main': {'feels_like': 306.89,
#           'grnd_level': 987,
#           'humidity': 58,
#           'pressure': 1006,
#           'sea_level': 1006,
#           'temp': 303.8,
#           'temp_max': 303.8,
#           'temp_min': 303.8},
#  'name': 'Tarauacá',
#  'sys': {'country': 'BR', 'sunrise': 1608805497, 'sunset': 1608850845},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 278, 'speed': 1.87}}

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Display the DataFrame 

df = pd.DataFrame({"city": city, "latitude": lat, "longitude": lng, "max_temp": maxtemp, "humidity": humidity,
                   "cloudiness": cloudiness, "windspeed": windspeed, "country": country, "date": date
                  })

df.head() 

# Use Map Function to format all relevant columns 
    # Convert date
    # Convert max_temp from Kelvin to Farenheit 


df["max_temp"] = fahr_to_celsius(data["temperature"])
# Out:
#                         city  latitude  longitude  max_temp  humidity  \
# 0                   Coruripe    -10.13     -36.18    300.90        69
# 1                George Town      5.41     100.34    299.15        94
# 2  Petropavlovsk-Kamchatskiy     53.05     158.65    256.15        77
# 3                       Hilo     19.73    -155.09    296.48        64
# 4                  Cape Town    -33.93      18.42    294.26        77
#
#    cloudiness  windspeed country        date
# 0          14       7.21      BR  1608837080
# 1          20       1.00      MY  1608837029
# 2          87       3.00      RU  1608837082
# 3           1       3.10      US  1608837083
# 4           0       3.10      ZA  1608837085

# %%
# Save to CSV 
df.to_csv("../output_data/weather_status.csv", index=True, header=True)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Verify if any cities have humidity > 100% 

# Method 1:
df.sort_values(by='humidity', ascending=False)

# Method 2: 
humidity_100 = df.loc[df['humidity'] > 100]
humidity_100.shape[0]

print(f"There are no cities that have humiity over 100% within this sample dataset")
# Out:
# There are no cities that have humiity over 100% within this sample dataset

# %%
#  Get the indices of cities that have humidity over 100%.
print(f"Not applicable.")
# Out:
# Not applicable.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
print(f"Not applicable.")
# Out:
# Not applicable.

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create the scatterplot

lat_temp = plt.scatter(df['latitude'],df['max_temp'],marker = "o", edgecolors="black") 
plt.title("Latitude vs. Temperature Plot") 
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature")

#Save Image

plt.savefig("../output_data/lat_temp.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create the scatterplot

lat_humid = plt.scatter(df['latitude'],df['humidity'],marker = "o", edgecolors="black") 
plt.title("Latitude vs. Humidity Plot") 
plt.xlabel("Latitude")
plt.ylabel("Humidity")

#Save Image

plt.savefig("../output_data/lat_humid.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create the scatterplot

lat_cloud = plt.scatter(df['latitude'],df['cloudiness'],marker = "o", edgecolors="black") 
plt.title("Latitude vs. Cloudiness Plot") 
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

#Save Image

plt.savefig("../output_data/lat_cloud.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create the scatterplot 
lat_wind = plt.scatter(df['latitude'],df['windspeed'],marker = "o", edgecolors="black") 
plt.title("Latitude vs. Wind Speed Plot") 
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

#Save Image
plt.savefig("../output_data/lat_wind.png")

# %% [markdown]
# ## Linear Regression

# %%
# The datatset (nested dictionaries) have no information specifically on hemisphere
    # If latitude > 0 --> hempisphere is Northern
    # If latitude < 0 --> hempisphere is Southern

# Create Northern and Southern Hemisphere DataFrames
northern_df = df.loc[pd.to_numeric(df["latitude"]).astype(float) > 0, :]
southern_df = df.loc[pd.to_numeric(df["latitude"]).astype(float) < 0, :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Assign x and y variables
x_values = pd.to_numeric(northern_df["latitude"]).astype(float)
y_values = pd.to_numeric(northern_df["max_temp"]).astype(float)

# Calculate linear regression - Northern Hemisphere - Max Temp vs. Latitude Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot linear regression on top of scatter plot
plt.scatter(x_values,y_values, edgecolors="black")
plt.plot(x_values,regress_values, color="red")


# Annotate linear regression
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature Observed")

#Save Image
plt.savefig("../output_data/northern_temp_latitude.png")

# Print r value
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.6784451020578289

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Assign x and y variables
x_values = pd.to_numeric(southern_df["latitude"]).astype(float)
y_values = pd.to_numeric(southern_df["max_temp"]).astype(float)

# Calculate linear regression - Northern Hemisphere - Max Temp vs. Latitude Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot linear regression on top of scatter plot
plt.scatter(x_values,y_values, edgecolors="black")
plt.plot(x_values,regress_values, color="red")


# # Annotate linear regression
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature Observed")

#Save Image
plt.savefig("../output_data/southern_temp_latitude.png")

# Print r value
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.3299374036387011

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Assign x and y variables
x_values = pd.to_numeric(northern_df["latitude"]).astype(float)
y_values = pd.to_numeric(northern_df["humidity"]).astype(float)

# Calculate linear regression - Northern Hemisphere - Max Temp vs. Latitude Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot linear regression on top of scatter plot
plt.scatter(x_values,y_values, edgecolors="black")
plt.plot(x_values,regress_values, color="red")


# # Annotate linear regression
plt.title("Northern Hemisphere - Humidity vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

#Save Image
plt.savefig("../output_data/northern_humidity_latitude.png")

# Print r value
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.16341831856967723

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Assign x and y variables
x_values = pd.to_numeric(southern_df["latitude"]).astype(float)
y_values = pd.to_numeric(southern_df["humidity"]).astype(float)

# Calculate linear regression - Northern Hemisphere - Max Temp vs. Latitude Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot linear regression on top of scatter plot
plt.scatter(x_values,y_values, edgecolors="black")
plt.plot(x_values,regress_values, color="red")


# # Annotate linear regression
plt.title("Northern Hemisphere - Humidity vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

#Save Image
plt.savefig("../output_data/southern_humidity_latitude.png")

# Print r value
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.06597619485875254

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Assign x and y variables
x_values = pd.to_numeric(northern_df["latitude"]).astype(float)
y_values = pd.to_numeric(northern_df["cloudiness"]).astype(float)

# Calculate linear regression - Northern Hemisphere - Max Temp vs. Latitude Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot linear regression on top of scatter plot
plt.scatter(x_values,y_values, edgecolors="black")
plt.plot(x_values,regress_values, color="red")


# # Annotate linear regression
plt.title("Northern Hemisphere - Cloudiness vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloud Coverage")

#Save Image
plt.savefig("../output_data/northern_clouds_latitude.png")

# Print r value
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.09187959914228133

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Assign x and y variables
x_values = pd.to_numeric(southern_df["latitude"]).astype(float)
y_values = pd.to_numeric(southern_df["cloudiness"]).astype(float)

# Calculate linear regression - Northern Hemisphere - Max Temp vs. Latitude Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot linear regression on top of scatter plot
plt.scatter(x_values,y_values, edgecolors="black")
plt.plot(x_values,regress_values, color="red")


# # Annotate linear regression
plt.title("Southern Hemisphere - Cloudiness vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloud Coverage")

#Save Image
plt.savefig("../output_data/southern_clouds_latitude.png")

# Print r value
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.10585621733868965

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Assign x and y variables
x_values = pd.to_numeric(northern_df["latitude"]).astype(float)
y_values = pd.to_numeric(northern_df["windspeed"]).astype(float)

# Calculate linear regression - Northern Hemisphere - Max Temp vs. Latitude Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot linear regression on top of scatter plot
plt.scatter(x_values,y_values, edgecolors="black")
plt.plot(x_values,regress_values, color="red")


# # Annotate linear regression
plt.title("Northern Hemisphere - Windspeed vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Windspeed")

#Save Image
plt.savefig("../output_data/northern_windspeed_latitude.png")

# Print r value
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.027648007599804438

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Assign x and y variables
x_values = pd.to_numeric(southern_df["latitude"]).astype(float)
y_values = pd.to_numeric(southern_df["windspeed"]).astype(float)

# Calculate linear regression - Northern Hemisphere - Max Temp vs. Latitude Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot linear regression on top of scatter plot
plt.scatter(x_values,y_values, edgecolors="black")
plt.plot(x_values,regress_values, color="red")


# # Annotate linear regression
plt.title("Southern Hemisphere - Windspeed vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Windspeed")

#Save Image
plt.savefig("../output_data/southern_windspeed_latitude.png")

# Print r value
print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.06261844454890078
